# %% [markdown]
# # NetCDF data manipulation and visualisation with `xarray`
#
# *Notebook by Marian Osei and Leif Denby*
#
# <b>Question</b>: How can I extract data, perform calculations and create quick plots in netCDF?
#
# <b>Objectives</b>:
#
#   1. Extract netcdf data into a variable
#
#   2.  Perform arithmetic with xarray: Mean, Max, Sum
#
#   3.  Plotting arithmetic of xarray dataset
#
#   4.  Plot 1D, 2D and 3D datasets with xarray
#
#   5.  Slicing/subsetting xarray dataset: Longitude, Latitude, Time
#
#   6.  Masking dataset with .where() function
#
#   7.  Using the groupby function on xarray dataset

# %% [markdown]
# <b>What is Xarray?</b>
#
# Xarray is an open source project and Python package that makes working with labelled multi-dimensional arrays simple, efficient, and fun!
#
# It is particularly tailored to working with netCDF files which are: numeric, multi-dimensional,    labelled, contains metadata and sometimes (very) large
#
# The [xarray documentation](http://xarray.pydata.org/en/stable/index.html) is a great place to get started, and in particular the [documentation on plotting](http://xarray.pydata.org/en/stable/user-guide/plotting.html) will be very useful.

# %% [markdown]
# # Demonstration of `xarray` functionality we will be using
#
# To begin our exercises on Xarray, python packages need to be imported

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path  # this module is useful for constructing paths
# %matplotlib inline

# %%
# Change the path below to where you've 
data_path = Path("../data/")

# %%
# (1) Opening and extracting data into a variable

ds = xr.open_dataset(data_path / 'ERA5_temp_rh_West_Africa.nc')

# print content of ds
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 77, level: 6, longitude: 153, time: 492)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2020-12-01T12:00:00
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Data variables:
#     r          (time, level, latitude, longitude) float32 ...
#     t          (time, level, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg...
#     Conventions:  CF-1.6
#     history:      Sat May 22 17:00:08 2021: cdo selday,1 ERA5_temperature_rh_...
#     CDO:          Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg...

# %%
# print dimensions use in the dataset
ds.dims
# Out:
# Frozen(SortedKeysDict({'time': 492, 'longitude': 153, 'latitude': 77, 'level': 6}))

# %%
# print attributes of the datasets
ds.attrs
# Out:
# {'CDI': 'Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg.de/cdi)',
#  'Conventions': 'CF-1.6',
#  'history': 'Sat May 22 17:00:08 2021: cdo selday,1 ERA5_temperature_rh_West_Africa.nc ERA5.nc\nSat May 22 16:46:41 2021: cdo selhour,12 ERA5_temperature_rh_West_Africa.nc ERA_extract3.nc\n2021-05-22 12:45:24 GMT by grib_to_netcdf-2.16.0: /opt/ecmwf/eccodes/bin/grib_to_netcdf -S param -o /cache/data3/adaptor.mars.internal-1621682428.5499933-6242-23-8c660e77-6ed3-4eb1-b99d-6b5f86cf9550.nc /cache/tmp/8c660e77-6ed3-4eb1-b99d-6b5f86cf9550-adaptor.mars.internal-1621682428.550575-6242-6-tmp.grib',
#  'CDO': 'Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg.de/cdo)'}

# %%
# select the temperature variable in the dataset
ds.t
# Out:
# <xarray.DataArray 't' (time: 492, level: 6, latitude: 77, longitude: 153)>
# [34777512 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2020-12-01T12:00:00
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %%
# print out the values of temperature in dataset
# (this will be the underlying numpy array, with the coordinate information stripped out)
ds.t.values
# Out:
# array([[[[262.42038, 262.39154, 262.37018, ..., 264.6173 , 264.66434,
#           264.6558 ],
#          [262.55716, 262.51978, 262.48557, ..., 264.81714, 264.84708,
#           264.85455],
#          [262.72064, 262.67792, 262.63516, ..., 264.91116, 264.97742,
#           265.00735],
#          ...,
#          [267.14017, 267.33252, 267.4447 , ..., 267.3571 , 267.43295,
#           267.50348],
#          [267.2716 , 267.4864 , 267.62744, ..., 267.34106, 267.25024,
#           267.2075 ],
#          [267.32077, 267.54944, 267.69583, ..., 267.3261 , 267.11026,
#           266.95212]],
#
#         [[272.96378, 272.68274, 272.36432, ..., 271.42398, 271.45285,
#           271.43893],
#          [273.2683 , 273.04712, 272.77997, ..., 271.70822, 271.74777,
#           271.8001 ],
#          [273.44568, 273.295  , 273.0952 , ..., 272.00635, 272.07153,
#           272.16022],
#          ...,
#          [274.43088, 274.29947, 273.98315, ..., 274.75467, 274.60828,
#           274.61362],
#          [274.46616, 274.30267, 273.99063, ..., 274.77817, 274.70123,
#           274.76428],
#          [274.5046 , 274.2952 , 273.9543 , ..., 274.82306, 274.84122,
#           274.91708]],
#
#         [[276.2079 , 276.16086, 276.14056, ..., 278.29797, 278.43475,
#           278.4668 ],
#          [276.44403, 276.39166, 276.35748, ..., 278.50742, 278.56296,
#           278.53198],
#          [276.72614, 276.65775, 276.60217, ..., 278.5309 , 278.59076,
#           278.5117 ],
#          ...,
#          [281.85516, 281.63077, 281.51752, ..., 281.67886, 281.62543,
#           281.57843],
#          [281.80496, 281.58484, 281.47797, ..., 281.6746 , 281.73764,
#           281.7323 ],
#          [281.79425, 281.59445, 281.4833 , ..., 281.53888, 281.68954,
#           281.8509 ]],
#
#         [[286.99597, 286.9885 , 286.99597, ..., 284.62912, 284.04892,
#           284.4667 ],
#          [287.07077, 287.07184, 287.08572, ..., 284.72852, 284.6035 ,
#           284.61737],
#          [287.06863, 287.0601 , 287.06436, ..., 284.8439 , 285.01807,
#           284.88132],
#          ...,
#          [289.58612, 289.3361 , 289.21106, ..., 292.66354, 292.8559 ,
#           293.47885],
#          [289.44507, 289.1897 , 289.09033, ..., 292.5054 , 292.842  ,
#           293.2908 ],
#          [289.31046, 289.0978 , 289.05826, ..., 292.85696, 293.01404,
#           293.16364]],
#
#         [[290.20483, 290.20056, 290.19412, ..., 290.5521 , 288.99307,
#           288.13824],
#          [290.56918, 290.5521 , 290.57135, ..., 290.7498 , 289.57758,
#           288.28677],
#          [290.90366, 290.8919 , 290.91968, ..., 290.9603 , 289.91312,
#           288.3605 ],
#          ...,
#          [293.1284 , 292.88153, 292.7907 , ..., 299.81003, 300.03976,
#           300.84863],
#          [293.0931 , 292.83133, 292.71378, ..., 299.59845, 299.97778,
#           300.5815 ],
#          [292.9756 , 292.82492, 292.6614 , ..., 300.0173 , 300.17654,
#           300.3411 ]],
#
#         [[290.40356, 289.9366 , 289.4269 , ..., 294.7451 , 293.32712,
#           292.64966],
#          [290.2978 , 289.78168, 289.31366, ..., 294.71732, 293.59427,
#           292.77255],
#          [290.1781 , 289.6823 , 289.3425 , ..., 294.7643 , 293.79944,
#           292.85376],
#          ...,
#          [297.58423, 297.5479 , 297.21985, ..., 305.22757, 305.34082,
#           306.12408],
#          [297.50302, 297.47525, 297.18994, ..., 304.96576, 305.25107,
#           305.83237],
#          [297.44424, 297.43036, 297.14932, ..., 305.3697 , 305.49042,
#           305.65714]]],
#
#
#        [[[262.98672, 263.11172, 263.225  , ..., 264.83636, 264.94644,
#           265.0736 ],
#          [262.98672, 263.08395, 263.17798, ..., 265.1345 , 265.2467 ,
#           265.35355],
#          [263.0273 , 263.08823, 263.14914, ..., 265.4134 , 265.52133,
#           265.59933],
#          ...,
#          [268.01852, 268.01852, 268.02814, ..., 268.09653, 267.74924,
#           267.30472],
#          [268.03882, 268.04843, 268.0709 , ..., 268.14142, 268.15958,
#           267.8732 ],
#          [268.04843, 268.07623, 268.1104 , ..., 267.87747, 268.10934,
#           268.2237 ]],
#
#         [[272.00208, 272.02023, 272.02557, ..., 272.20724, 272.29272,
#           272.32156],
#          [271.923  , 271.95612, 271.97858, ..., 272.53207, 272.54062,
#           272.59512],
#          [271.84714, 271.89737, 271.93475, ..., 272.84302, 272.85263,
#           272.9413 ],
#          ...,
#          [274.92242, 274.9598 , 275.00684, ..., 273.996  , 273.86243,
#           274.08575],
#          [275.01645, 275.0528 , 275.09552, ..., 274.33685, 273.99707,
#           273.95325],
#          [275.19705, 275.23123, 275.2654 , ..., 274.22147, 274.2022 ,
#           274.2877 ]],
#
#         [[278.5544 , 278.4668 , 278.38025, ..., 279.47766, 279.53748,
#           279.65823],
#          [278.86856, 278.7756 , 278.67517, ..., 279.60052, 279.74478,
#           279.8837 ],
#          [279.16776, 279.0716 , 278.9701 , ..., 279.7373 , 279.9446 ,
#           280.091  ],
#          ...,
#          [282.0582 , 282.04324, 282.04218, ..., 282.15222, 282.0849 ,
#           281.6575 ],
#          [282.16183, 282.16504, 282.17255, ..., 282.18536, 282.1907 ,
#           281.8541 ],
#          [282.27512, 282.29648, 282.3157 , ..., 282.31036, 282.2719 ,
#           282.14902]],
#
#         [[286.6829 , 286.5365 , 286.39438, ..., 284.60135, 284.69858,
#           285.64426],
#          [286.75128, 286.6348 , 286.5055 , ..., 284.4272 , 284.87064,
#           285.48184],
#          [286.794  , 286.70425, 286.60275, ..., 284.24338, 284.89627,
#           285.33545],
#          ...,
#          [290.57135, 290.5681 , 290.57776, ..., 293.88812, 293.886  ,
#           293.42114],
#          [290.44632, 290.4367 , 290.4602 , ..., 293.63593, 293.91376,
#           293.89987],
#          [290.26678, 290.27643, 290.33197, ..., 293.62845, 293.75775,
#           293.89453]],
#
#         [[289.72504, 289.79343, 289.8554 , ..., 290.8246 , 289.2677 ,
#           288.5646 ],
#          [289.89816, 289.93982, 289.99646, ..., 290.5895 , 289.6898 ,
#           288.77298],
#          [290.07446, 290.0937 , 290.1172 , ..., 290.40463, 289.7368 ,
#           288.91614],
#          ...,
#          [293.92337, 293.90628, 293.91055, ..., 301.04846, 300.5623 ,
#           299.35162],
#          [293.80905, 293.83362, 293.88065, ..., 300.6371 , 300.90207,
#           300.98007],
#          [293.7011 , 293.75775, 293.81653, ..., 300.70117, 300.78348,
#           301.09763]],
#
#         [[290.9464 , 290.6985 , 290.4837 , ..., 294.85623, 293.44254,
#           293.00336],
#          [291.0009 , 290.769  , 290.62262, ..., 294.56558, 293.62204,
#           293.09525],
#          [291.0479 , 290.8278 , 290.7925 , ..., 294.6051 , 293.7898 ,
#           293.21066],
#          ...,
#          [298.36105, 298.40594, 298.42303, ..., 306.45212, 305.78427,
#           304.42508],
#          [298.18048, 298.26062, 298.27878, ..., 305.9873 , 306.12622,
#           306.22772],
#          [298.05225, 298.07147, 298.1089 , ..., 306.05035, 306.05035,
#           306.39978]]],
#
#
#        [[[261.29626, 261.27277, 261.24927, ..., 267.0707 , 266.98523,
#           266.9692 ],
#          [261.52814, 261.49823, 261.4694 , ..., 267.1562 , 267.11133,
#           267.08246],
#          [261.77713, 261.74292, 261.71194, ..., 267.1252 , 267.1423 ,
#           267.10385],
#          ...,
#          [267.72574, 267.6723 , 267.6253 , ..., 267.6787 , 267.51523,
#           267.38486],
#          [267.73535, 267.70972, 267.69366, ..., 267.6114 , 267.42868,
#           267.25772],
#          [267.6691 , 267.6894 , 267.7108 , ..., 267.56973, 267.35068,
#           267.14017]],
#
#         [[269.63736, 269.38733, 269.14157, ..., 272.76608, 272.69662,
#           272.65817],
#          [269.95367, 269.71323, 269.47388, ..., 273.03964, 272.95203,
#           272.9969 ],
#          [270.21973, 269.99426, 269.76453, ..., 273.27686, 273.2715 ,
#           273.33456],
#          ...,
#          [274.5901 , 274.58795, 274.56232, ..., 274.42447, 274.4202 ,
#           274.38602],
#          [274.5153 , 274.52493, 274.50354, ..., 274.51102, 274.5292 ,
#           274.48004],
#          [274.40845, 274.4405 , 274.45868, ..., 274.6756 , 274.67453,
#           274.52386]],
#
#         [[275.72385, 275.63513, 275.5582 , ..., 277.2508 , 277.14392,
#           277.15677],
#          [275.7356 , 275.65546, 275.59882, ..., 277.77972, 277.57562,
#           277.5329 ],
#          [275.78687, 275.7292 , 275.69818, ..., 277.95496, 278.00198,
#           277.9635 ],
#          ...,
#          [281.42563, 281.5186 , 281.69382, ..., 282.4557 , 282.31143,
#           282.05927],
#          [281.4951 , 281.58804, 281.759  , ..., 282.32855, 282.1875 ,
#           281.8167 ],
#          [281.6575 , 281.71945, 281.8637 , ..., 282.15436, 281.9898 ,
#           281.67886]],
#
#         [[280.9405 , 281.042  , 281.11038, ..., 280.0397 , 277.9913 ,
#           277.88336],
#          [281.1061 , 281.1884 , 281.24075, ..., 279.65503, 278.2392 ,
#           277.96994],
#          [281.22366, 281.31555, 281.37753, ..., 279.4456 , 278.5865 ,
#           278.07678],
#          ...,
#          [289.7571 , 289.84473, 289.93982, ..., 292.15707, 292.1998 ,
#           292.05768],
#          [289.8148 , 289.89923, 289.97723, ..., 292.22974, 292.1859 ,
#           292.00107],
#          [289.87357, 289.94836, 289.96973, ..., 292.2372 , 292.0598 ,
#           291.85788]],
#
#         [[284.75842, 284.88025, 285.05975, ..., 286.29822, 285.18692,
#           284.71994],
#          [284.75522, 284.8781 , 285.0651 , ..., 286.856  , 285.63037,
#           284.77872],
#          [284.7488 , 284.87384, 285.05548, ..., 286.9853 , 285.95947,
#           284.9283 ],
#          ...,
#          [293.4094 , 293.37415, 293.47137, ..., 296.32867, 295.91943,
#           295.2163 ],
#          [293.37415, 293.40298, 293.5013 , ..., 295.9408 , 295.45248,
#           294.9171 ],
#          [293.34637, 293.47137, 293.56006, ..., 295.42468, 294.84875,
#           294.78784]],
#
#         [[289.63742, 289.52417, 289.3767 , ..., 290.41745, 289.5049 ,
#           289.20038],
#          [289.6278 , 289.51132, 289.3425 , ..., 290.58737, 289.5188 ,
#           289.2848 ],
#          [289.61606, 289.47928, 289.27518, ..., 290.4367 , 289.6246 ,
#           289.44507],
#          ...,
#          [297.6024 , 297.68466, 297.61414, ..., 301.7612 , 301.3156 ,
#           300.47357],
#          [297.94113, 298.0886 , 297.73596, ..., 301.35086, 300.6531 ,
#           299.88376],
#          [297.83533, 298.064  , 297.80542, ..., 300.58472, 299.64545,
#           299.27682]]],
#
#
#        ...,
#
#
#        [[[265.10992, 264.9646 , 264.82675, ..., 265.19754, 265.423  ,
#           265.67627],
#          [265.06396, 264.92722, 264.79578, ..., 265.27875, 265.47324,
#           265.7019 ],
#          [265.0095 , 264.8802 , 264.75516, ..., 265.4444 , 265.54056,
#           265.73074],
#          ...,
#          [268.3284 , 268.2867 , 268.3348 , ..., 266.56207, 266.69885,
#           266.8463 ],
#          [268.43417, 268.39465, 268.41815, ..., 266.3612 , 266.55566,
#           266.75763],
#          [268.556  , 268.5229 , 268.51324, ..., 266.18274, 266.3815 ,
#           266.63687]],
#
#         [[273.20312, 273.2437 , 273.31424, ..., 274.7536 , 274.64993,
#           274.3999 ],
#          [273.03644, 273.0781 , 273.13794, ..., 274.68307, 274.5463 ,
#           274.36142],
#          [272.94455, 272.9798 , 273.02896, ..., 274.6072 , 274.4747 ,
#           274.35715],
#          ...,
#          [274.6756 , 274.6211 , 274.63605, ..., 274.6243 , 274.7162 ,
#           274.822  ],
#          [274.71512, 274.64993, 274.64673, ..., 274.63498, 274.7087 ,
#           274.77176],
#          [274.84122, 274.76962, 274.75574, ..., 274.62323, 274.6692 ,
#           274.70337]],
#
#         [[282.5914 , 282.61917, 282.66833, ..., 283.36502, 283.39816,
#           283.115  ],
#          [282.70682, 282.7506 , 282.80084, ..., 283.5232 , 283.52747,
#           283.35007],
#          [282.8222 , 282.87137, 282.91196, ..., 283.5627 , 283.6995 ,
#           283.6247 ],
#          ...,
#          [282.64804, 282.7346 , 282.79123, ..., 282.4653 , 282.38516,
#           282.2719 ],
#          [282.67368, 282.7506 , 282.81686, ..., 282.42578, 282.35526,
#           282.26016],
#          [282.71643, 282.77307, 282.83182, ..., 282.3574 , 282.2986 ,
#           282.23663]],
#
#         [[296.3148 , 296.33936, 296.3789 , ..., 297.53293, 297.68787,
#           298.1153 ],
#          [296.2913 , 296.31265, 296.3415 , ..., 297.84174, 297.9999 ,
#           298.14307],
#          [296.24426, 296.26135, 296.334  , ..., 298.33542, 298.2307 ,
#           298.19543],
#          ...,
#          [289.91846, 289.8223 , 289.78702, ..., 290.91968, 290.78503,
#           291.03937],
#          [290.07233, 289.9099 , 289.83832, ..., 291.34177, 291.20926,
#           290.97098],
#          [290.20697, 289.99432, 289.87463, ..., 291.68903, 291.58005,
#           291.10135]],
#
#         [[300.19363, 300.85828, 301.50473, ..., 304.04788, 305.28528,
#           305.70413],
#          [300.70547, 301.36795, 301.95352, ..., 304.7467 , 305.5727 ,
#           305.83664],
#          [301.15427, 301.7879 , 302.28372, ..., 305.2564 , 305.7234 ,
#           306.02042],
#          ...,
#          [292.61548, 292.74475, 292.77576, ..., 297.57462, 297.54895,
#           298.1356 ],
#          [292.54175, 292.58875, 292.54495, ..., 296.56696, 296.84586,
#           297.56714],
#          [292.4552 , 292.43167, 292.42633, ..., 296.21115, 296.60223,
#           297.19208]],
#
#         [[293.9768 , 293.74387, 293.43185, ..., 308.58817, 309.66632,
#           310.06808],
#          [294.0623 , 293.89667, 293.47244, ..., 309.32654, 309.77747,
#           310.11084],
#          [294.20334, 294.04733, 293.57074, ..., 309.9281 , 309.85333,
#           310.19952],
#          ...,
#          [298.5566 , 298.44547, 298.27344, ..., 302.96118, 302.80624,
#           303.39285],
#          [298.49036, 298.43372, 298.3258 , ..., 301.84134, 302.05612,
#           302.79126],
#          [298.438  , 298.41235, 298.35892, ..., 301.46094, 301.85522,
#           302.45682]]],
#
#
#        [[[264.4517 , 264.40683, 264.3427 , ..., 259.8142 , 259.79175,
#           259.74582],
#          [264.5468 , 264.47095, 264.38757, ..., 259.92105, 259.88898,
#           259.79175],
#          [264.63016, 264.5543 , 264.48483, ..., 260.08026, 259.99905,
#           259.88257],
#          ...,
#          [267.75778, 267.636  , 267.56012, ..., 267.83472, 267.8219 ,
#           267.8561 ],
#          [267.8283 , 267.65842, 267.5644 , ..., 267.9138 , 267.81442,
#           267.761  ],
#          [267.91486, 267.72467, 267.60498, ..., 268.00037, 267.85397,
#           267.7685 ]],
#
#         [[272.55557, 272.72443, 272.87296, ..., 270.71555, 270.70593,
#           270.74973],
#          [272.65817, 272.83875, 273.00116, ..., 270.61615, 270.6226 ,
#           270.6792 ],
#          [272.83127, 272.9894 , 273.14114, ..., 270.6728 , 270.66745,
#           270.69418],
#          ...,
#          [275.1126 , 275.03247, 274.93417, ..., 275.0464 , 275.01218,
#           275.03568],
#          [275.1575 , 275.11047, 275.0186 , ..., 274.9363 , 274.92136,
#           274.92136],
#          [275.212  , 275.19168, 275.11368, ..., 274.76   , 274.7974 ,
#           274.83694]],
#
#         [[279.1026 , 279.25754, 279.5001 , ..., 279.218  , 278.90704,
#           278.9423 ],
#          [279.03635, 279.19662, 279.44238, ..., 279.17953, 279.12717,
#           279.01923],
#          [278.97437, 279.11008, 279.32486, ..., 278.9904 , 279.218  ,
#           278.99146],
#          ...,
#          [282.27618, 282.3937 , 282.4803 , ..., 282.4728 , 282.45462,
#           282.28046],
#          [282.27725, 282.3937 , 282.48456, ..., 282.3157 , 282.2858 ,
#           282.1426 ],
#          [282.31357, 282.41617, 282.507  , ..., 282.21634, 282.22168,
#           282.09775]],
#
#         [[293.7396 , 293.6616 , 293.55685, ..., 285.82376, 284.9016 ,
#           285.2553 ],
#          [293.7396 , 293.71286, 293.67334, ..., 285.76498, 285.3333 ,
#           285.34933],
#          [293.7866 , 293.793  , 293.79834, ..., 286.0567 , 285.78638,
#           285.4252 ],
#          ...,
#          [289.9099 , 289.97186, 290.08942, ..., 291.81406, 291.97006,
#           292.3772 ],
#          [289.83725, 289.9238 , 290.08408, ..., 291.77347, 291.969  ,
#           292.37506],
#          [289.8319 , 289.96118, 290.0937 , ..., 291.55228, 291.73605,
#           291.9957 ]],
#
#         [[299.1251 , 298.9958 , 298.91458, ..., 292.2575 , 292.2543 ,
#           292.28955],
#          [299.59525, 299.45312, 299.36337, ..., 292.95526, 292.83347,
#           292.4039 ],
#          [300.04297, 299.93503, 299.8442 , ..., 293.44894, 293.18393,
#           292.56097],
#          ...,
#          [293.3891 , 293.55258, 293.6584 , ..., 299.1037 , 299.1037 ,
#           299.57385],
#          [293.36667, 293.50345, 293.52908, ..., 299.12936, 299.2501 ,
#           299.71918],
#          [293.33566, 293.40405, 293.45856, ..., 298.88464, 298.9338 ,
#           299.20096]],
#
#         [[299.33984, 299.65936, 300.13806, ..., 296.4569 , 296.61826,
#           296.86508],
#          [299.44244, 299.9842 , 300.8027 , ..., 296.90356, 296.86508,
#           296.95486],
#          [299.44672, 300.2246 , 301.37225, ..., 297.3064 , 297.12476,
#           297.08948],
#          ...,
#          [298.5331 , 298.55447, 298.5876 , ..., 304.5191 , 304.3332 ,
#           304.75742],
#          [298.47433, 298.49356, 298.56195, ..., 304.53836, 304.50522,
#           304.95294],
#          [298.46793, 298.44867, 298.5502 , ..., 304.28616, 304.22632,
#           304.50308]]],
#
#
#        [[[264.45276, 264.49124, 264.52115, ..., 264.82782, 264.84387,
#           264.90582],
#          [264.68143, 264.73486, 264.79257, ..., 265.10352, 265.1623 ,
#           265.20822],
#          [264.99237, 265.06396, 265.14093, ..., 265.47537, 265.54163,
#           265.58008],
#          ...,
#          [267.2887 , 267.27054, 267.29297, ..., 268.7387 , 268.7697 ,
#           268.868  ],
#          [267.26627, 267.28015, 267.3336 , ..., 268.821  , 268.86053,
#           268.9268 ],
#          [267.27588, 267.3293 , 267.3945 , ..., 268.8413 , 268.85413,
#           268.9065 ]],
#
#         [[274.12314, 274.09857, 274.03445, ..., 272.55344, 272.49255,
#           272.3141 ],
#          [274.0911 , 274.03125, 273.93936, ..., 272.73083, 272.60474,
#           272.46048],
#          [274.02377, 273.9415 , 273.85388, ..., 272.83447, 272.70837,
#           272.62503],
#          ...,
#          [274.76962, 274.84335, 274.92456, ..., 274.65527, 274.7835 ,
#           274.8252 ],
#          [274.83694, 274.83267, 274.8583 , ..., 274.67026, 274.7632 ,
#           274.78885],
#          [274.81662, 274.76642, 274.7472 , ..., 274.7675 , 274.81662,
#           274.82626]],
#
#         [[280.97043, 281.0217 , 281.09116, ..., 279.5161 , 279.42316,
#           279.31415],
#          [281.1745 , 281.23328, 281.24716, ..., 279.7373 , 279.57703,
#           279.4413 ],
#          [281.3412 , 281.33905, 281.2525 , ..., 279.8121 , 279.78326,
#           279.65503],
#          ...,
#          [282.1661 , 282.08383, 281.98233, ..., 282.56256, 282.6726 ,
#           282.5743 ],
#          [281.9321 , 281.88297, 281.83914, ..., 282.5914 , 282.6395 ,
#           282.55722],
#          [281.83487, 281.82846, 281.82098, ..., 282.6758 , 282.6224 ,
#           282.6053 ]],
#
#         [[286.7972 , 287.13275, 287.45117, ..., 286.97247, 284.12906,
#           283.77216],
#          [287.34216, 287.59756, 287.79095, ..., 286.50443, 284.48807,
#           284.2423 ],
#          [287.698  , 287.86362, 287.96515, ..., 286.14862, 284.87918,
#           284.45175],
#          ...,
#          [289.2773 , 289.22498, 289.2773 , ..., 295.30502, 295.0667 ,
#           295.44604],
#          [289.26343, 289.19183, 289.29333, ..., 295.06458, 294.83804,
#           295.25372],
#          [289.36493, 289.31686, 289.43546, ..., 294.84982, 294.79105,
#           295.0603 ]],
#
#         [[287.58902, 287.8273 , 288.09442, ..., 293.26193, 291.33322,
#           290.38754],
#          [287.6061 , 287.80594, 288.32846, ..., 293.39337, 291.79163,
#           290.7177 ],
#          [287.35074, 287.53986, 288.40112, ..., 292.9542 , 291.92307,
#           291.0415 ],
#          ...,
#          [293.19034, 293.20212, 293.18607, ..., 302.63205, 302.32645,
#           302.77203],
#          [293.27798, 293.3207 , 293.29935, ..., 302.38202, 302.06467,
#           302.57544],
#          [293.39124, 293.46924, 293.43826, ..., 302.13733, 302.04007,
#           302.3596 ]],
#
#         [[292.66354, 292.58554, 291.9177 , ..., 297.42502, 295.60956,
#           294.87653],
#          [292.826  , 292.64432, 291.83542, ..., 297.4934 , 295.83182,
#           295.1287 ],
#          [293.01297, 292.7747 , 291.93375, ..., 297.23267, 296.05408,
#           295.4172 ],
#          ...,
#          [297.89197, 297.65796, 297.5169 , ..., 308.0774 , 307.5837 ,
#           308.03677],
#          [298.064  , 297.96036, 297.92725, ..., 307.79422, 307.27917,
#           307.79102],
#          [298.21466, 298.14844, 298.18903, ..., 307.48648, 307.28345,
#           307.6425 ]]]], dtype=float32)

# %%
# select temperature variable through subsetting or slicing. First let's select temperature for a
# certain point location (6.66 N, 1.51 W), extracting at all pressure levels and timesteps. 

ds.t.sel(longitude=-1.51, latitude=6.66, method='nearest')
# Out:
# <xarray.DataArray 't' (time: 492, level: 6)>
# array([[266.35266, 274.45547, 282.98462, 289.74   , 295.5636 , 301.35086],
#        [266.76404, 275.8681 , 281.94064, 292.0502 , 297.01575, 302.71967],
#        [268.48868, 274.19046, 281.28244, 291.68796, 296.59903, 302.44827],
#        ...,
#        [267.31647, 275.2772 , 282.67154, 289.93982, 293.69577, 299.51724],
#        [268.41495, 276.20895, 282.34244, 292.88046, 296.67917, 302.39804],
#        [266.99057, 275.67255, 283.63217, 291.6901 , 297.21344, 302.97827]],
#       dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2020-12-01T12:00:00
#     longitude  float32 -1.5
#     latitude   float32 6.75
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %%
# Use the slice function to subset across any coordinate of the dataset. For instance, select temperature
# between pressure levels 1000 to 700 only.

ds.t.sel(level=slice(850,1000))
# Out:
# <xarray.DataArray 't' (time: 492, level: 3, latitude: 77, longitude: 153)>
# array([[[[286.99597, ..., 284.4667 ],
#          ...,
#          [289.31046, ..., 293.16364]],
#
#         ...,
#
#         [[290.40356, ..., 292.64966],
#          ...,
#          [297.44424, ..., 305.65714]]],
#
#
#        ...,
#
#
#        [[[286.7972 , ..., 283.77216],
#          ...,
#          [289.36493, ..., 295.0603 ]],
#
#         ...,
#
#         [[292.66354, ..., 294.87653],
#          ...,
#          [298.21466, ..., 307.6425 ]]]], dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2020-12-01T12:00:00
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 850.0 925.0 1e+03
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %% [markdown]
# (2) Now let us do some calculations on the temperature dataset.

# %%
print (ds.t.units)
# Out:
# K

# %%
# Convert the temperature from kelvin to celsius
da_temp_C = ds.t - 273.15
da_temp_C.attrs["units"] = "celsius"
da_temp_C.attrs["long_name"] = ds.t.long_name
da_temp_C
# Out:
# <xarray.DataArray 't' (time: 492, level: 6, latitude: 77, longitude: 153)>
# array([[[[-1.07296143e+01, -1.07584534e+01, -1.07798157e+01, ...,
#           -8.53268433e+00, -8.48565674e+00, -8.49420166e+00],
#          [-1.05928345e+01, -1.06302185e+01, -1.06644287e+01, ...,
#           -8.33285522e+00, -8.30291748e+00, -8.29544067e+00],
#          [-1.04293518e+01, -1.04720764e+01, -1.05148315e+01, ...,
#           -8.23883057e+00, -8.17257690e+00, -8.14263916e+00],
#          ...,
#          [-6.00982666e+00, -5.81747437e+00, -5.70529175e+00, ...,
#           -5.79290771e+00, -5.71704102e+00, -5.64651489e+00],
#          [-5.87838745e+00, -5.66360474e+00, -5.52255249e+00, ...,
#           -5.80892944e+00, -5.89974976e+00, -5.94250488e+00],
#          [-5.82922363e+00, -5.60055542e+00, -5.45416260e+00, ...,
#           -5.82388306e+00, -6.03973389e+00, -6.19787598e+00]],
#
#         [[-1.86218262e-01, -4.67254639e-01, -7.85675049e-01, ...,
#           -1.72601318e+00, -1.69714355e+00, -1.71105957e+00],
#          [ 1.18316650e-01, -1.02874756e-01, -3.70025635e-01, ...,
#           -1.44177246e+00, -1.40222168e+00, -1.34988403e+00],
#          [ 2.95684814e-01,  1.45019531e-01, -5.47790527e-02, ...,
#           -1.14364624e+00, -1.07846069e+00, -9.89776611e-01],
# ...
#            2.94820557e+01,  2.91764526e+01,  2.96220398e+01],
#          [ 2.01279907e+01,  2.01707153e+01,  2.01493530e+01, ...,
#            2.92320251e+01,  2.89146729e+01,  2.94254456e+01],
#          [ 2.02412415e+01,  2.03192444e+01,  2.02882690e+01, ...,
#            2.89873352e+01,  2.88900757e+01,  2.92095947e+01]],
#
#         [[ 1.95135498e+01,  1.94355469e+01,  1.87677002e+01, ...,
#            2.42750244e+01,  2.24595642e+01,  2.17265320e+01],
#          [ 1.96759949e+01,  1.94943237e+01,  1.86854248e+01, ...,
#            2.43434143e+01,  2.26818237e+01,  2.19786987e+01],
#          [ 1.98629761e+01,  1.96246948e+01,  1.87837524e+01, ...,
#            2.40826721e+01,  2.29040833e+01,  2.22672119e+01],
#          ...,
#          [ 2.47419739e+01,  2.45079651e+01,  2.43669128e+01, ...,
#            3.49273987e+01,  3.44337158e+01,  3.48867798e+01],
#          [ 2.49140015e+01,  2.48103638e+01,  2.47772522e+01, ...,
#            3.46442261e+01,  3.41291809e+01,  3.46410217e+01],
#          [ 2.50646667e+01,  2.49984436e+01,  2.50390320e+01, ...,
#            3.43364868e+01,  3.41334534e+01,  3.44924927e+01]]]],
#       dtype=float32)
# Coordinates:
#   * time       (time) datetime64[ns] 1980-01-01T12:00:00 ... 2020-12-01T12:00:00
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Attributes:
#     units:      celsius
#     long_name:  Temperature

# %%
# Compute the mean of the temperature over time
tmean = ds.t.mean('time')
tmean
# Out:
# <xarray.DataArray 't' (level: 6, latitude: 77, longitude: 153)>
# array([[[263.60248, 263.59555, 263.5858 , ..., 265.00903, 265.06073,
#          265.08215],
#         [263.679  , 263.6706 , 263.66043, ..., 265.1139 , 265.14246,
#          265.17944],
#         [263.75443, 263.7449 , 263.73456, ..., 265.19342, 265.22687,
#          265.2729 ],
#         ...,
#         [267.55035, 267.54794, 267.5486 , ..., 267.62802, 267.627  ,
#          267.6232 ],
#         [267.56104, 267.5588 , 267.55682, ..., 267.62534, 267.6273 ,
#          267.62183],
#         [267.56778, 267.56833, 267.56546, ..., 267.61896, 267.62207,
#          267.61777]],
#
#        [[272.87555, 272.8762 , 272.8778 , ..., 273.9731 , 274.00183,
#          274.00134],
#         [272.90784, 272.91058, 272.9149 , ..., 274.06747, 274.0736 ,
#          274.0917 ],
#         [272.94162, 272.94458, 272.95056, ..., 274.1136 , 274.15338,
#          274.1821 ],
# ...
#         [293.01157, 293.00323, 292.98557, ..., 298.5182 , 298.43216,
#          298.66467],
#         [292.96405, 292.95807, 292.94736, ..., 298.28317, 298.29892,
#          298.47574],
#         [292.9239 , 292.92194, 292.9255 , ..., 298.18927, 298.19772,
#          298.30328]],
#
#        [[292.22186, 292.10333, 292.00232, ..., 303.15814, 302.82986,
#          302.68933],
#         [292.2458 , 292.16147, 292.1028 , ..., 303.47147, 302.96906,
#          302.74097],
#         [292.27466, 292.2417 , 292.2697 , ..., 303.75543, 303.11243,
#          302.8132 ],
#         ...,
#         [297.96515, 297.9797 , 297.9595 , ..., 303.90588, 303.6819 ,
#          303.90347],
#         [297.91797, 297.93628, 297.92023, ..., 303.637  , 303.5105 ,
#          303.67258],
#         [297.88977, 297.8921 , 297.88696, ..., 303.47537, 303.41687,
#          303.53043]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03

# %% [markdown]
# You can see that this data-array hasn't got any attributes set (i.e. the units and "long_name" information has gone). You can tell xarray to retain these attributes with `keep_attrs=True`:

# %%
ds.t.mean(dim="time", keep_attrs=True)
# Out:
# <xarray.DataArray 't' (level: 6, latitude: 77, longitude: 153)>
# array([[[263.60248, 263.59555, 263.5858 , ..., 265.00903, 265.06073,
#          265.08215],
#         [263.679  , 263.6706 , 263.66043, ..., 265.1139 , 265.14246,
#          265.17944],
#         [263.75443, 263.7449 , 263.73456, ..., 265.19342, 265.22687,
#          265.2729 ],
#         ...,
#         [267.55035, 267.54794, 267.5486 , ..., 267.62802, 267.627  ,
#          267.6232 ],
#         [267.56104, 267.5588 , 267.55682, ..., 267.62534, 267.6273 ,
#          267.62183],
#         [267.56778, 267.56833, 267.56546, ..., 267.61896, 267.62207,
#          267.61777]],
#
#        [[272.87555, 272.8762 , 272.8778 , ..., 273.9731 , 274.00183,
#          274.00134],
#         [272.90784, 272.91058, 272.9149 , ..., 274.06747, 274.0736 ,
#          274.0917 ],
#         [272.94162, 272.94458, 272.95056, ..., 274.1136 , 274.15338,
#          274.1821 ],
# ...
#         [293.01157, 293.00323, 292.98557, ..., 298.5182 , 298.43216,
#          298.66467],
#         [292.96405, 292.95807, 292.94736, ..., 298.28317, 298.29892,
#          298.47574],
#         [292.9239 , 292.92194, 292.9255 , ..., 298.18927, 298.19772,
#          298.30328]],
#
#        [[292.22186, 292.10333, 292.00232, ..., 303.15814, 302.82986,
#          302.68933],
#         [292.2458 , 292.16147, 292.1028 , ..., 303.47147, 302.96906,
#          302.74097],
#         [292.27466, 292.2417 , 292.2697 , ..., 303.75543, 303.11243,
#          302.8132 ],
#         ...,
#         [297.96515, 297.9797 , 297.9595 , ..., 303.90588, 303.6819 ,
#          303.90347],
#         [297.91797, 297.93628, 297.92023, ..., 303.637  , 303.5105 ,
#          303.67258],
#         [297.88977, 297.8921 , 297.88696, ..., 303.47537, 303.41687,
#          303.53043]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %%
# Extract the overall maximum temperature value, this will be just a single value
tmax = ds.t.max(keep_attrs=True)
tmax
# Out:
# <xarray.DataArray 't' ()>
# array(318.7618, dtype=float32)
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %%
# Extract the maximum temperature over time at all pressure levels, longitudes and latitudes
# this will retain the dimensions of (level, latitute, longitude)
ttmax = ds.t.max('time', keep_attrs=True)
ttmax
# Out:
# <xarray.DataArray 't' (level: 6, latitude: 77, longitude: 153)>
# array([[[270.74225, 270.69095, 270.63113, ..., 272.0042 , 272.19012,
#          272.27563],
#         [270.6044 , 270.5638 , 270.49542, ..., 272.0555 , 272.2083 ,
#          272.266  ],
#         [270.47192, 270.42383, 270.33514, ..., 272.13245, 272.23502,
#          272.26065],
#         ...,
#         [269.912  , 269.93442, 269.9868 , ..., 270.86942, 270.97305,
#          271.11624],
#         [269.94513, 269.90665, 269.89597, ..., 270.7818 , 270.82773,
#          270.988  ],
#         [269.90024, 269.9013 , 269.86926, ..., 270.77753, 270.86194,
#          271.13226]],
#
#        [[277.87802, 277.97742, 278.08105, ..., 280.13052, 280.06   ,
#          280.0814 ],
#         [277.99878, 278.11417, 278.21356, ..., 279.84308, 279.84525,
#          279.87622],
#         [278.1206 , 278.22958, 278.3033 , ..., 279.63687, 279.67105,
#          279.6422 ],
# ...
#         [295.88736, 295.7677 , 295.78052, ..., 304.2477 , 304.12054,
#          304.486  ],
#         [295.82755, 295.6512 , 295.63733, ..., 304.0703 , 303.95706,
#          304.23596],
#         [295.70358, 295.554  , 295.58817, ..., 303.85342, 303.90363,
#          304.21777]],
#
#        [[301.665  , 303.1781 , 304.46356, ..., 316.20157, 316.65356,
#          316.61084],
#         [301.57632, 303.21548, 304.67407, ..., 316.60977, 316.42917,
#          316.5029 ],
#         [302.4504 , 303.17166, 304.52017, ..., 316.70166, 316.33728,
#          316.43558],
#         ...,
#         [301.22583, 301.2376 , 301.24936, ..., 309.72937, 309.39597,
#          309.69196],
#         [301.1564 , 301.20447, 301.21088, ..., 309.54877, 309.26456,
#          309.4975 ],
#         [301.11685, 301.1735 , 301.20447, ..., 309.30515, 309.2934 ,
#          309.54987]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Temperature
#     units:          K

# %%
# We make computations on multiple dimensions. For example: find the maximum of temperature across time
# and latitude

ds.t.max(['time','latitude'])
# Out:
# <xarray.DataArray 't' (level: 6, longitude: 153)>
# array([[271.4368 , 271.36737, 271.28934, 271.21667, 271.16647, 271.1419 ,
#         271.17715, 271.18997, 271.1793 , 271.1558 , 271.11624, 271.05853,
#         270.99658, 270.9282 , 270.8427 , 270.74332, 270.66318, 270.69202,
#         270.74332, 270.83093, 270.9816 , 271.01367, 271.02222, 271.03076,
#         271.17502, 271.15152, 271.00833, 270.85233, 270.73584, 270.74225,
#         270.81064, 270.89185, 270.9752 , 271.04785, 271.14618, 271.24768,
#         271.34384, 271.4229 , 271.51053, 271.6003 , 271.68045, 271.72745,
#         271.68045, 271.59924, 271.5255 , 271.45178, 271.3695 , 271.24875,
#         271.3353 , 271.43253, 271.40796, 271.2701 , 271.15472, 271.11304,
#         271.13333, 271.14725, 271.11304, 271.05106, 271.0094 , 271.15686,
#         271.59924, 271.9882 , 272.25104, 272.34616, 272.30447, 272.15274,
#         271.95505, 271.75632, 271.56183, 271.4304 , 271.4785 , 271.5223 ,
#         271.5629 , 271.59174, 271.61847, 271.63235, 271.65265, 271.66333,
#         271.6719 , 271.67725, 271.6954 , 271.73065, 271.7606 , 271.80118,
#         271.80972, 271.8279 , 271.83646, 271.83432, 271.8108 , 271.78088,
#         271.74133, 271.7018 , 271.65906, 271.61313, 271.51053, 271.3214 ,
#         271.23166, 271.33423, 271.55542, 271.71036, 271.88345, 271.95932,
#         271.90698, 271.74884, 271.66013, 271.64944, 271.7969 , 271.85355,
#         271.8621 , 271.79263, 271.7061 , 271.68045, 271.72318, 271.79263,
#         271.79904, 271.9497 , 272.03946, 272.06726, 272.0277 , 271.99567,
# ...
#         316.3127 , 316.36932, 316.40674, 316.83737, 316.94528, 316.88437,
#         316.76364, 316.68777, 316.59158, 316.9517 , 317.74243, 318.27884,
#         318.46262, 318.50003, 318.5043 , 318.4594 , 318.28738, 318.1207 ,
#         318.06833, 318.00208, 318.22433, 318.5278 , 318.75754, 318.7618 ,
#         318.51605, 318.11322, 317.6345 , 317.66122, 317.46994, 317.18997,
#         317.1761 , 317.45712, 317.4197 , 317.3898 , 317.45605, 317.42078,
#         317.37378, 317.2701 , 317.4582 , 317.77768, 317.93475, 318.01062,
#         317.923  , 317.86957, 317.93796, 317.8482 , 317.86636, 317.7371 ,
#         317.7531 , 317.77982, 317.69006, 317.70822, 317.69754, 317.88776,
#         318.00635, 317.96362, 317.88882, 317.77554, 318.063  , 318.19016,
#         318.07474, 318.1057 , 318.19443, 318.2019 , 318.1709 , 318.22754,
#         318.4092 , 318.52567, 318.4049 , 318.25317, 318.12177, 317.97324,
#         317.88348, 317.86636, 317.97003, 317.92087, 317.68045, 317.5159 ,
#         317.69434, 317.80334, 317.85995, 317.88562, 318.07153, 318.04056,
#         317.93262, 317.85034, 317.9647 , 317.97644, 317.69434, 317.60886,
#         317.76273, 317.87598, 317.9369 , 318.03094, 318.25   , 318.5107 ,
#         318.48828, 318.51498, 318.20084, 318.3002 , 318.12604, 317.7296 ,
#         317.46033, 317.88348, 318.4498 , 318.1303 , 317.8717 , 317.88455,
#         317.94437, 317.7499 , 317.40903, 317.2466 , 317.0906 , 317.03503,
#         317.17288, 317.17288, 317.24234]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#   * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03

# %% [markdown]
# Because xarray knows what the coordinates in our data mean, for example after taking the max over latitude, longitude and level only the "time"-coordinate will remain. This allows xarray to work out what kind of plot to use when we call `.plot()` on any xarray `DataArray`. For example calling `.plot()` on the output of our previous example will create a heatmap plot because the resulting data is 2D:

# %%
ds.t.max(['time','latitude']).plot()

# %%
# In conjuction with matplotlib, n-dimensional plots can be made with xarray. Let us plot the timeseries
# of temperature at longitude 1.51 W, latitude 6.66 N and at the surface pressure (1000 mb)

ds.t.sel(longitude=-1.51, latitude=6.66, method='nearest', level=1000).plot()

# %%
# plot the vertical profile of temperature at longitude 1.51 W, latitude 6.66 N, averaged over time

ds.t.sel(longitude=-1.51, latitude=6.66, method='nearest').mean('time').T.plot(y='level',
                                                                               yincrease=False)

# %%
# Plot the temperature at time 1980-01-01T12, averaged over all pressure levels

ds.t.sel(time='1980-01-01T12').mean('level').plot()

# %%
#Plot the temperature at pressure level 1000mb, for all times, averaged over longitudes. This time
#evolution plot is also known as the 'Hovmoller plot'.

ds.t.sel(level=925).mean('latitude').plot()

# %%
# Plot the hovmoller of temperature from 1980 Jan to 1980 Dec at level 925, averaged over latitudes.

ds.t.sel(time=slice('1980-01-01T12', '1980-12-01T12'),level=925).mean('latitude').plot()

# %% [markdown]
# <b>Exercise 1</b>:
#
# 1. Compute the sum, maximum and mean of relative humidity over time
# 2. Compute and plot the difference in relative humidity at the 925mb and 600mb level on (a) 1990-06-01 and (b) 2020-06-01 respectively. What observations can be made from both plots?
# 3. Plot the time-evolution (Hovmoller) of the relative humidity averaged over all pressure levels and longitudes
# 4. From Question 3, plot the Hovmoller from between 1990 and 2000. Hint: Use slice to subset
# 5. From Question 3, plot the Hovmoller for 2020 Jan to Dec relative humidity only.

# %%
ds.r.sum('time'),ds.r.max('time'),ds.r.mean('time')
# Out:
# (<xarray.DataArray 'r' (level: 6, latitude: 77, longitude: 153)>
#  array([[[14272.948 , 14339.7705, 14432.932 , ..., 10437.038 ,
#            9817.665 ,  9762.171 ],
#          [14323.629 , 14383.453 , 14469.085 , ..., 10150.567 ,
#            9965.921 ,  9838.744 ],
#          [14369.422 , 14418.023 , 14493.776 , ..., 10295.777 ,
#           10206.853 ,  9988.864 ],
#          ...,
#          [23894.795 , 23961.621 , 23932.438 , ..., 26731.773 ,
#           26695.322 , 26690.951 ],
#          [23455.096 , 23457.111 , 23407.895 , ..., 26900.418 ,
#           26865.777 , 26849.008 ],
#          [22962.273 , 22848.646 , 22761.408 , ..., 27085.86  ,
#           27074.748 , 27046.418 ]],
#
#         [[15516.315 , 15619.557 , 15726.6045, ..., 11981.557 ,
#           11397.96  , 11419.376 ],
#          [15919.494 , 16024.783 , 16141.566 , ..., 11879.584 ,
#           11681.528 , 11537.225 ],
#          [16317.821 , 16428.824 , 16546.121 , ..., 12189.993 ,
#           11919.758 , 11643.232 ],
#  ...
#          [44455.88  , 44578.746 , 44628.86  , ..., 34261.51  ,
#           34806.035 , 33946.75  ],
#          [44419.56  , 44490.65  , 44555.863 , ..., 35101.973 ,
#           35224.656 , 34592.965 ],
#          [44377.36  , 44363.824 , 44333.094 , ..., 35304.348 ,
#           35441.754 , 35095.85  ]],
#
#         [[37661.19  , 37452.64  , 36863.176 , ...,  9143.952 ,
#            9040.853 ,  9198.312 ],
#          [37501.01  , 37084.082 , 36385.227 , ...,  8755.745 ,
#            8971.034 ,  9137.63  ],
#          [37370.902 , 36658.457 , 35658.406 , ...,  8533.847 ,
#            8901.997 ,  8980.371 ],
#          ...,
#          [40127.703 , 40084.945 , 40076.727 , ..., 29093.523 ,
#           30391.422 , 29444.408 ],
#          [40130.605 , 40096.81  , 40065.85  , ..., 30078.92  ,
#           30948.059 , 30347.617 ],
#          [40075.254 , 40057.82  , 40035.07  , ..., 30741.887 ,
#           31196.82  , 30796.725 ]]], dtype=float32)
#  Coordinates:
#    * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#    * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#    * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03,
#  <xarray.DataArray 'r' (level: 6, latitude: 77, longitude: 153)>
#  array([[[101.38778 ,  99.670395,  99.15238 , ...,  95.40164 ,
#            95.494064,  97.432846],
#          [100.34961 ,  99.32433 ,  98.8923  , ...,  94.53757 ,
#            98.681656,  97.381256],
#          [ 98.93529 ,  97.389854,  99.01697 , ...,  95.80788 ,
#            99.326485,  99.54358 ],
#          ...,
#          [101.48021 , 100.99873 ,  99.15238 , ...,  99.32219 ,
#            98.1529  ,  97.25229 ],
#          [ 97.310326, 102.372215, 102.191666, ...,  99.71338 ,
#            99.06641 ,  99.567215],
#          [100.88696 , 104.54314 , 103.98428 , ...,  96.72353 ,
#            99.234055, 101.43722 ]],
#
#         [[ 99.09865 ,  98.58278 ,  98.32915 , ...,  90.99747 ,
#            88.443954,  89.66268 ],
#          [ 99.41031 ,  98.984726,  98.46457 , ...,  88.43536 ,
#            88.43536 ,  87.99688 ],
#          [ 99.597305,  99.19107 ,  98.53549 , ...,  88.910385,
#            88.203224,  85.94203 ],
#  ...
#          [100.757996, 101.02023 , 100.10887 , ...,  99.74562 ,
#           100.10028 ,  99.812256],
#          [100.24858 ,  99.68114 ,  99.74562 , ..., 100.10672 ,
#           100.64838 , 100.24214 ],
#          [100.29802 , 100.26793 , 100.0143  , ..., 100.15186 ,
#           100.1927  ,  99.91757 ]],
#
#         [[100.0014  , 100.15401 ,  99.55217 , ...,  54.534676,
#            48.78927 ,  52.746353],
#          [100.325966,  99.676834,  99.83804 , ...,  46.882732,
#            49.4298  ,  53.330997],
#          [100.571   ,  99.498436, 100.282974, ...,  48.656006,
#            50.558243,  52.746353],
#          ...,
#          [ 94.29039 ,  93.73584 ,  93.516594, ...,  92.51282 ,
#            93.35539 ,  93.83686 ],
#          [ 94.02386 ,  93.75518 ,  93.368286, ...,  95.03194 ,
#            94.70093 ,  97.7875  ],
#          [ 94.253845,  94.10554 ,  93.66276 , ...,  96.69559 ,
#            98.458115,  99.29854 ]]], dtype=float32)
#  Coordinates:
#    * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#    * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#    * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03,
#  <xarray.DataArray 'r' (level: 6, latitude: 77, longitude: 153)>
#  array([[[29.010057, 29.145876, 29.335226, ..., 21.213491, 19.954603,
#           19.84181 ],
#          [29.113068, 29.234661, 29.408709, ..., 20.631235, 20.255938,
#           19.997448],
#          [29.206142, 29.304926, 29.458895, ..., 20.926376, 20.745636,
#           20.30257 ],
#          ...,
#          [48.566658, 48.70248 , 48.643166, ..., 54.332874, 54.258785,
#           54.2499  ],
#          [47.67296 , 47.677055, 47.577023, ..., 54.675648, 54.60524 ,
#           54.571156],
#          [46.671288, 46.44034 , 46.263023, ..., 55.05256 , 55.029976,
#           54.972393]],
#
#         [[31.537226, 31.747066, 31.964643, ..., 24.352757, 23.166586,
#           23.210114],
#          [32.356697, 32.570698, 32.808064, ..., 24.145496, 23.742943,
#           23.449644],
#          [33.1663  , 33.39192 , 33.63033 , ..., 24.77641 , 24.22715 ,
#           23.665106],
#  ...
#          [90.357475, 90.60721 , 90.70906 , ..., 69.63722 , 70.74397 ,
#           68.99746 ],
#          [90.28365 , 90.42815 , 90.5607  , ..., 71.345474, 71.59483 ,
#           70.310905],
#          [90.19788 , 90.17037 , 90.10792 , ..., 71.756805, 72.03609 ,
#           71.33303 ]],
#
#         [[76.547134, 76.12325 , 74.925156, ..., 18.585268, 18.375717,
#           18.695755],
#          [76.221565, 75.37415 , 73.95371 , ..., 17.79623 , 18.233809,
#           18.572418],
#          [75.957115, 74.509056, 72.47643 , ..., 17.345217, 18.09349 ,
#           18.252787],
#          ...,
#          [81.56037 , 81.473465, 81.456764, ..., 59.13318 , 61.771183,
#           59.84636 ],
#          [81.56627 , 81.49758 , 81.434654, ..., 61.136017, 62.902557,
#           61.682148],
#          [81.453766, 81.418335, 81.37209 , ..., 62.48351 , 63.408173,
#           62.594967]]], dtype=float32)
#  Coordinates:
#    * longitude  (longitude) float32 -18.0 -17.75 -17.5 -17.25 ... 19.5 19.75 20.0
#    * latitude   (latitude) float32 22.0 21.75 21.5 21.25 ... 3.75 3.5 3.25 3.0
#    * level      (level) float64 500.0 600.0 700.0 850.0 925.0 1e+03)

# %%
#2a
(ds.r.sel(level=925, time='1990-01-01')-ds.r.sel(level=600,time='1990-01-01')).plot()

# %%
#2b
(ds.r.sel(level=925, time='1990-06-01')-ds.r.sel(level=600,time='1990-06-01')).plot()

# %%
#3
a=ds.r.mean(dim=['level', 'longitude'])
a.plot()

# %%
#4
a.sel(time=slice('1990-01-01','2000-01-01')).plot()

# %%
#5
a.sel(time=slice('2020-01-01','2020-12-01')).plot()
